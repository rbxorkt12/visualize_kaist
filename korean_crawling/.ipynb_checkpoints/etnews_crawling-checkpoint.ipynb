# %%
import requests 
from bs4 import BeautifulSoup as bs
import pandas as pd
from tqdm import tqdm
import time
import re

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'}

eng_url_head = 'https://search.etnews.com/etnews/search.php?category=CATEGORY1&kwd=kaist&pageNum='

eng_url_tail = '&pageSize=10&reSrchFlag=false&sort=1&startDate=&endDate=&sitegubun=&jisikgubun=&preKwd%5B0%5D=kaist#&pageNum=340'

url1 = []
# url 변화하는거 적당히 보고 알아서 잘 해야됨. 페이지 단위로 넘어가는게 아니라면 selenium 써야할 수도 있음.
for i in tqdm(range(340)):
    url_final = eng_url_head + str(i) +eng_url_tail
    try:
        response = requests.get(url_final, headers=headers)
        html = response.content
        soup = bs(html, "html.parser")
#            page가 넘어갔을 때 검색결과가 없는 경우 while 문 break
        elements = soup.select('.thumb a[href]') # F12 눌러서 적당히 우리가 원하는 a href 태그 url 링크 달려있는 id 또는 class 찾아서 넣어주면 됨.
    except:
        print('Request Failed_1')
    for element in elements:
        link = element.attrs['href']
        url1.append(link)
# Out:
# Request Failed_1
# Request Failed_1

# %%
url = list(set(url1))
df = pd.DataFrame({"url": url}, columns=["url"])
print("Total number of articles: ", len(df))
df.head()
# Out:
# Total number of articles:  0
# Empty DataFrame
# Columns: [url]
# Index: []

# %%
contents = []
titles = []
urls = []
for row in tqdm(df.itertuples()):
    link = getattr(row, 'url')
    response = requests.get(link, headers=headers)
    html = response.text
    soup = bs(html,'html.parser')
    try:
        title = soup.select('.nd-news-tit')[0].get_text()
        content = soup.select('.nd-center')[0].get_text() # select 안에 본문에 해당하는 id 값을 찾아서 넣어주면 됨.
        content = content.replace('\xa0', " ")
        content = content.replace('\n', " ")
        title = title.replace('\xa0', " ")
        title = title.replace('\n', " ")
        titles.append(title)
        contents.append(content)
        urls.append(link)
    except:
        print(row)
df = pd.DataFrame({"urls": urls, "titles": titles, "contents": contents}, columns=["urls", "titles", "contents"])
df.to_excel("articles/newdaily.xlsx",index = False)
df.to_pickle("pickle files/newdaily.pkl")
# Out:
# 1384it [05:52,  3.93it/s]

# %%
response = requests.get('http://biz.newdaily.co.kr/site/data/html/2015/01/03/2015010310009.html', headers=headers)
html = response.text
soup = bs(html,'html.parser')
try:
    title = soup.select('.nd-news-tit')[0].get_text()
    content = soup.select('p') # select 안에 본문에 해당하는 id 값을 찾아서 넣어주면 됨.
    content = content.replace('\xa0', " ")
    content = content.replace('\n', " ")
    title = title.replace('\xa0', " ")
    title = title.replace('\n', " ")
    print(title)
except:
    print(row)
# Out:
# Pandas(Index=1383, url='http://cc.newdaily.co.kr/site/data/html/2017/06/08/2017060800042.html')

# %%
response = requests.get('https://www.ytn.co.kr/search/?callSite=1&sort=date&q=카이스트&x=36&y=44&se_date=3&ds=20150101&de=20201023&target=0&mtarget=0#type=1&page=1', headers=headers)
html = response.content
soup = bs(html, "html.parser")
#            page가 넘어갔을 때 검색결과가 없는 경우 while 문 break
elements = soup.select('body') # F12 눌러서 적당히 우리가 원하는 a href 태그 url 링크 달려있는 id 또는 class 찾아서 넣어주면 됨.
print(elements)
# Out:
# [<body>
# <div class="container">
# <div class="header ">
# <div class="header_wrap">
# <div class="gnb_header wrapper">
# <div class="YTN_CSA_hammenu">
# <a class="btn_menu" href="javascript:void(0);" onclick="$('#hammenu, #menu_black').show();"><span class="blind">메뉴</span></a>
# </div>
# <!---------------------- 햄버거 메뉴 : 공통 ---------------------->
# <div class="menu" id="hammenu" style="display:none;">
# <div class="menu_top">
# <div><span class="ico"></span><span class="blind">YTN</span></div>
# <button class="menu_close" onclick="$('#hammenu, #menu_black').hide(); hamMenuChange();"><span class="blind">메뉴 닫기</span></button>
# <ul style="left:0;float:right">
# <li><a href="https://www.ytn.co.kr">HOME</a></li>
# <li><a href="https://www.ytn.co.kr/info/webpush.php">뉴스알림</a></li>
# <li><a href="https://www.ytn.co.kr/_hd/hd_live.html">라이브</a></li>
# <li><a href="https://www.ytn.co.kr/hd/hd_live.php?sort=1 ">편성표</a></li>
# <li><a href="https://mj.ytn.co.kr">제보</a></li>
# ...
